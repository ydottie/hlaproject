# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pylab as P

root = '..'

# %%
# runtime plot
data = pd.read_csv(root+'/results/cpu_ram/runtime_data - cpu.csv')
df = data.melt()
sns.set_context("paper")
sns.color_palette("pastel")
sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

my_order = ["Optitype ","HLA-HD","PHLAT","HLAforest","arcasHLA","HLAMiner","rna2hla","seq2HLA","HLAvbseq"]

ax = sns.boxplot(x="variable",y="value", data=df[12:],order=my_order,showfliers=False)
ax = sns.stripplot(x="variable", y="value", data=df[12:],order=my_order,jitter=True,s=5,color='black',edgecolor='black')

ax.set_ylabel("CPU Time (s)")
ax.set_xlabel("Callers")
ax.set_title("CPU Time (s)") 
ax.set_yscale('log')
sns.despine()
plt.savefig(root+'/Figures/cpu.png',bbox_inches ="tight",dpi=300)

# %%
# CPU time plot

gs = pd.read_csv(root+'/results/cpu_ram/runtime_data - ram.csv')
df = gs.melt()
sns.set_context("paper")
sns.color_palette("pastel")
sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")

my_order = ["Optitype ","HLA-HD","PHLAT","HLAforest","arcasHLA","HLAMiner","rna2hla","seq2HLA","HLAvbseq"]

ax1 = sns.boxplot(x="variable",y="value", data=df[12:],order=my_order,showfliers=False)
ax1.set_ylabel("RAM (bytes)")
ax1.set_xlabel("Callers")
ax1.set_title("RAM (bytes)") 
ax1.set_yscale('log')
sns.despine()

ax1 = sns.stripplot(x="variable", y="value", data=df[12:],order=my_order,jitter=True,s=5,color='black',edgecolor='black')

plt.savefig(root+'/Figures/ram.png',bbox_inches ="tight",dpi=300)

# %%
# Wallclock time plot

means = 13 # means stored in index 13
gs = pd.read_csv(root+'MASTER RESULTS DIRECTORY/runtime/wallclock-time.csv')
df = gs.melt()
sns.set_context("paper")
sns.color_palette("pastel")
sns.set(rc={'figure.figsize':(10,10)})
sns.set_style("white")
ax = sns.boxplot(x="variable",y="value", data=df[14:])
ax.set_ylabel("CPU Time (s)")
ax.set_xlabel("Callers")
ax.set_title("Dataset 1 CPU Time (s)") 

sns.despine()
plt.savefig(root+'/Figures/d1_wallclock-time.png',bbox_inches ="tight",dpi=300)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       1 # Wallclock time plot
#       3 means = 13 # means stored in index 13
# ----> 4 gs = pd.read_csv(root+'MASTER RESULTS DIRECTORY/runtime/wallclock-time.csv')
#       5 df = gs.melt()
#       6 sns.set_context("paper")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
