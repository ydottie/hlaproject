# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pylab as P

root = '..'

# %%
my_order = ["Optitype ","HLA-HD","PHLAT","HLAforest","arcasHLA","HLAMiner","seq2HLA"]

sns.set_context("paper")
sns.set_style("white")
sns.set(font_scale=2)

# %%
# runtime plot


data = pd.read_csv(root+'/results/cpu_ram/runtime_data - cpu.csv')
df = data.melt()
sns.set(rc={'figure.figsize':(10,10)})


ax = sns.boxplot(x="variable",y="value", data=df[12:],order=my_order,showfliers=False)
ax = sns.stripplot(x="variable", y="value", data=df[12:],order=my_order,jitter=True,s=5,color='black',edgecolor='black')

ax.set_ylabel("CPU Time (s)")
ax.set_xlabel("Callers")
ax.set_xticklabels(labels=my_order, rotation = 45)

ax.set_yscale('log')

sns.despine()
plt.savefig(root+'/Figures/cpu.png',bbox_inches ="tight",dpi=300)

# %%
# ram

data = pd.read_csv(root+'/results/cpu_ram/runtime_data - ram.csv')
df = data.melt()
sns.set(rc={'figure.figsize':(10,10)})

my_order = ["Optitype ","HLA-HD","PHLAT","HLAforest","arcasHLA","HLAMiner","rna2hla","seq2HLA","HLAvbseq"]

ax1 = sns.boxplot(x="variable",y="value", data=df[12:],order=my_order,showfliers=False)
ax1 = sns.stripplot(x="variable", y="value", data=df[12:],order=my_order,jitter=True,s=5,color='black',edgecolor='black')

ax1.set_xticklabels(labels=my_order, rotation = 45)
ax1.set_ylabel("RAM (bytes)")
ax1.set_xlabel("Callers")
ax1.set_title("RAM (bytes)") 
ax1.set_yscale('log')
sns.despine()

plt.savefig(root+'/Figures/ram.png',bbox_inches ="tight",dpi=300)

# %%
data = pd.read_csv(root+'/results/cpu_ram/runtime_data - ram.csv')
np.median(np.array(data['rna2hla']))

data = pd.read_csv(root+'/results/cpu_ram/runtime_data - cpu.csv')
np.median(np.array(data['rna2hla']))
# Out:
# 252.0

# %%
fig, ax = plt.subplots(2, 1,figsize=(15, 25))

# cpu plot
data = pd.read_csv(root+'/results/cpu_ram/runtime_data - cpu.csv')
df = data.melt()

my_order = ["Optitype ","HLA-HD","PHLAT","HLAforest","arcasHLA","HLAMiner","rna2hla","seq2HLA","HLAvbseq"]

sns.boxplot(ax=ax[0],x="variable",y="value", data=df[12:],order=my_order,showfliers=False)
sns.stripplot(ax=ax[0],x="variable", y="value", data=df[12:],order=my_order,jitter=True,s=5,color='black',edgecolor='black')
ax[0].set_ylabel("CPU Time (s)",size=25)
ax[0].set_xlabel("")
ax[0].set_title("CPU Time (s)") 
ax[0].set_yscale('log')
ax[0].set_xticklabels(labels=my_order, rotation = 45,size = 20)
ax[0].set_yticklabels(ax[0].get_yticks(),size = 20)


# ram

data1 = pd.read_csv(root+'/results/cpu_ram/runtime_data - ram.csv')
df1 = data1.melt()

my_order = ["Optitype ","HLA-HD","PHLAT","HLAforest","arcasHLA","HLAMiner","rna2hla","seq2HLA","HLAvbseq"]

sns.boxplot(ax=ax[1],x="variable",y="value", data=df1[12:],order=my_order,showfliers=False)
sns.stripplot(ax=ax[1],x="variable", y="value", data=df1[12:],order=my_order,jitter=True,s=5,color='black',edgecolor='black')

ax[1].set_ylabel("RAM (bytes)",size=25)
ax[1].set_title("RAM (bytes)") 
ax[1].set_xlabel("")
ax[1].set_yscale('log')
ax[1].set_xticklabels(labels=my_order, rotation = 45,size = 20)
ax[1].set_yticklabels(ax[1].get_yticks(),size = 20)


sns.despine()
#plt.savefig(root+'/Figures/cpu.png',bbox_inches ="tight",dpi=300)
# Out:
# /var/folders/j4/pd1pbcl90xz683wfkd2drjqw0000gn/T/ipykernel_54834/4007364450.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(ax[0].get_yticks(),size = 20)
# /var/folders/j4/pd1pbcl90xz683wfkd2drjqw0000gn/T/ipykernel_54834/4007364450.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels(ax[1].get_yticks(),size = 20)
