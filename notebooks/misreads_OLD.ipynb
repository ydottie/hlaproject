# %%
import pandas as pd
import glob
import collections
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Functions

# %%
# to select specific allele we are counting mismatches for
def select_allele(dataset,allele):
    df=dataset.set_index(dataset.columns[0])
    mask = df.apply(lambda col: col.str.contains(allele).any(),
                    axis=0)
    df=df.loc[: , mask]
    df=df.reset_index()
    df=df.iloc[: , :3]
    df=df.fillna(allele+'*00:00')
    df.columns=['Run',allele,allele+'.1']
    return df

# %%
# to select specific allele we are counting mismatches for
def select_allele_d5(dataset,allele):
    df=dataset.set_index(dataset.columns[0])
    mask = df.apply(lambda col: col.str.contains(allele).any(),
                    axis=0)
    df=df.loc[: , mask]
    df=df.reset_index()
    df=df.fillna(allele+'*00:00')
    df.columns=['Run',allele]
    return df

# %%
#counts a specific number of mismatches for a allele between a prediction set and gs 
def count_mismatch(pred,gs,allele):
    mismatch_count=0
    match=0
    pred=pd.read_csv('../results/standard/'+pred+'_d'+gs+'.csv')
    gs=pd.read_csv('../datasets/'+gs+'_gs.csv')
    pred=select_allele(pred,allele)
    gs=select_allele(gs,allele)
    if allele=='A' or allele=='B' or allele=='C':
        index_char=7
    elif allele=='DRB1' or allele=='DQB1':
        index_char=10
    for index_i,row_i in pred.iterrows():
        for index_j, row_j in gs.iterrows():
            if row_i[0]==row_j[0]:
                if row_i[allele][:index_char] != row_j[allele] and row_i[allele][:index_char] != row_j[allele+'.1']:
                    #print(row_i[allele][:index_char],row_j[allele],row_j[allele+'.1'],row_i[0],row_j[0])
                    mismatch_count+=1 
                elif row_i[allele+'.1'][:index_char] != row_j[allele] and row_i[allele+'.1'][:index_char] != row_j[allele+'.1']:
                    mismatch_count+=1
                    #print(row_i[allele+'.1'][:index_char],row_j[allele],row_j[allele+'.1'],row_i[0],row_j[0])
                else:
                    match+=1
                
    return mismatch_count
    #print(match)

# %%
count_mismatch('hlavbseq','3','DRB1')
# Out:
# 55

# %%
#counts a specific number of mismatches for a allele between a prediction set and gs 
def count_mismatch_d2(pred,gs,allele):
    mismatch_count=0
    match=0
    pred=pd.read_csv('../results/standard/'+pred+'_d'+gs+'.csv')
    gs=pd.read_csv('../datasets/'+gs+'_gs.csv')
    pred=select_allele(pred,allele)
    gs=select_allele(gs,allele)
    if allele=='A' or allele=='B' or allele=='C':
        index_char=7
    elif allele=='DRB1' or allele=='DQB1':
        index_char=10
    for index_i,row_i in pred.iterrows():
        for index_j, row_j  in gs.iterrows():
            if row_i[0]==row_j[0]:
                if '/' in row_j[allele] or '/' in row_j[allele+'.1']:
                    gs_1=row_j[allele].split('/')
                    gs_2=row_j[allele+'.1'].split('/')
                    gs_1[:]=(elem[:index_char] for elem in gs_1)
                    gs_2[:]=(elem[:index_char] for elem in gs_2)
                    if row_i[allele][:index_char] not in gs_1 and row_i[allele][:index_char] not in gs_2:
                        #print(row_i[allele][:index_char],gs_1,gs_2,row_i[0],row_j[0])
                        mismatch_count+=1
                    if row_i[allele+'.1'][:index_char] not in gs_1 and row_i[allele+'.1'][:index_char] not in gs_2:
                        #print (row_i[allele+'.1'][:index_char],gs_1,gs_2,row_i[0],row_j[0])
                        mismatch_count+=1
    return mismatch_count

# %%
#counts a specific number of mismatches for a allele between a prediction set and gs 
def count_mismatch_d5(pred,gs,allele):
    mismatch_count=0
    match=0
    pred=pd.read_csv('../results/standard/'+pred+'_d'+gs+'.csv')
    gs=pd.read_csv('../datasets/'+gs+'_gs.csv')
    pred=select_allele(pred,allele)
    gs=select_allele_d5(gs,allele)
    if allele=='A' or allele=='B' or allele=='C':
        index_char=7
    elif allele=='DRB1' or allele=='DQB1':
        index_char=10
    for index_i,row_i in pred.iterrows():
        for index_j, row_j  in gs.iterrows():
            if row_i[0]==row_j[0]:
                if row_i[allele][:index_char] != row_j[allele]:
                    #print(row_i[allele][:index_char],row_j[allele],row_i[0],row_j[0])
                    mismatch_count+=1 
                elif row_i[allele+'.1'][:index_char] != row_j[allele]:
                    #print(row_i[allele+'.1'][:index_char],row_j[allele],row_i[0],row_j[0])
                    mismatch_count+=1 
                
    return mismatch_count

# %%
#counts a specific number of mismatches for a allele between a prediction set and gs 
def count_mismatch_d6(pred,gs,allele):
    mismatch_count=0
    match=0
    pred=pd.read_csv('../results/standard/'+pred+'_d'+gs+'.csv')
    gs=pd.read_csv('../datasets/'+gs+'_gs.csv')
    pred=select_allele(pred,allele)
    if allele=='A' or allele=='B' or allele=='C':
        index_char=7
    elif allele=='DRB1' or allele=='DQB1':
        index_char=10
    for index_i,row_i in pred.iterrows():
        for index_j, row_j  in gs.iterrows():
            if row_i[0]==row_j[0]:
                if row_i[allele][:index_char] != row_j[allele]:
                    #print(row_i[allele][:index_char],row_j[allele],row_i[0],row_j[0])
                    mismatch_count+=1 
                elif row_i[allele+'.1'][:index_char] != row_j[allele]:
                    #print(row_i[allele+'.1'][:index_char],row_j[allele],row_i[0],row_j[0])
                    mismatch_count+=1 
                
    return mismatch_count

# %%
def mismatch_df(tool_list,gs_list,allele_list):
    df=[]
    for tool in tool_list:
        for gs in gs_list:
            for allele in allele_list:
                if gs=='2':
                    mismatch=count_mismatch_d2(tool,gs,allele)
                elif gs=='5':
                    mismatch=count_mismatch_d5(tool,gs,allele)
                elif gs=='6':
                    mismatch=count_mismatch_d6(tool,gs,allele)
                else:
                    mismatch=count_mismatch(tool,gs,allele)
                df.append([tool,gs,allele,mismatch])
    df=pd.DataFrame(df, columns=['Tool','GS','Allele','Mismatch'])
    return df

# %%
mismatch_count=0
match=0
allele='A'
pred=pd.read_csv('../results/standard/hlavbseq_d2.csv')
gs=pd.read_csv('../datasets/2_gs.csv')
gs
# Out:
#            Run                                                  A  \
# 0    ERR188021    A*01:01/A*01:04/A*01:22/A*01:32/A*01:34/A*01:37
# 1    ERR188023  A*02:01/A*02:09/A*02:43/A*02:66/A*02:75/A*02:8...
# 2    ERR188025    A*03:01/A*03:20/A*03:21/A*03:26/A*03:37/A*03:45
# 3    ERR188026                                    A*02:05/A*02:17
# 4    ERR188027                                            A*01:01
# ..         ...                                                ...
# 485  ERR205017                                         A*30:02:00
# 486  ERR205019                                         A*24:24:00
# 487  ERR205021    A*03:01/A*03:20/A*03:21/A*03:26/A*03:37/A*03:45
# 488  ERR205022                                            A*01:01
# 489  ERR205023                                            A*02:01
#
#                                                    A.1  \
# 0    A*24:02/A*24:09/A*24:11/A*24:40/A*24:76/A*24:7...
# 1                                      A*30:01/A*30:24
# 2                              A*31:01/A*31:14/A*31:23
# 3    A*24:02/A*24:09/A*24:11/A*24:40/A*24:76/A*24:7...
# 4                                              A*02:01
# ..                                                 ...
# 485                                         A*30:02:00
# 486                                         A*74:01:00
# 487                                         A*33:01:00
# 488                                            A*11:01
# 489                                            A*11:01
#
#                                    B  \
# 0                         B*41:02:00
# 1                            B*13:02
# 2    B*44:02/B*44:19/B*44:27/B*44:66
# 3                            B*15:17
# 4                            B*08:01
# ..                               ...
# 485                          B*15:03
# 486                          B*14:03
# 487                          B*15:10
# 488                       B*51:01:00
# 489                          B*15:01
#
#                                                  B.1                C  \
# 0                                B*1/B*2/B*1900 9:01          C*06:02
# 1                                    B*56:01/B*56:24  C*01:02/C*01:25
# 2    B*51:01/B*51:11/B*51:30/B*51:32/B*51:48/B*51:51  C*01:02/C*01:25
# 3                                         B*55:01:00  C*01:02/C*01:25
# 4                                         B*57:01:00  C*07:01/C*07:06
# ..                                               ...              ...
# 485                                       B*57:03:00          C*02:02
# 486                                       B*58:01:00          C*07:01
# 487                                  B*58:01/B*58:11          C*03:02
# 488                                       B*50:01:00          C*15:02
# 489                                       B*51:01:00          C*03:04
#
#                                  C.1        DRB1      DRB1.1  \
# 0            C*17:01/C*17:02/C*17:03  DRB1*13:03  DRB1*04:07
# 1                            C*06:02  DRB1*04:01  DRB1*07:01
# 2                    C*07:04/C*07:11  DRB1*16:01  DRB1*13:01
# 3    C*07:01/C*07:06/C*07:18/C*07:52  DRB1*11:01  DRB1*13:02
# 4                            C*06:02  DRB1*03:01  DRB1*07:01
# ..                               ...         ...         ...
# 485                          C*08:02  DRB1*13:03  DRB1*07:01
# 486                          C*08:02  DRB1*13:01  DRB1*07:01
# 487                          C*08:04  DRB1*03:01  DRB1*13:01
# 488                          C*06:02  DRB1*04:07  DRB1*07:01
# 489                          C*15:02  DRB1*04:01  DRB1*04:04
#
#                                                   DQB1  \
# 0    DQB1*03:01/DQB1*03:09/DQB1*03:19/DQB1*03:21/DQ...
# 1                     DQB1*02:01/DQB1*02:02/DQB1*02:04
# 2                                           DQB1*05:02
# 3    DQB1*03:01/DQB1*03:09/DQB1*03:19/DQB1*03:21/DQ...
# 4                                           DQB1*02:01
# ..                                                 ...
# 485                                         DQB1*02:01
# 486                                         DQB1*05:01
# 487  DQB1*03:01/DQB1*03:09/DQB1*03:19/DQB1*03:21/DQ...
# 488                                         DQB1*03:01
# 489                                         DQB1*03:01
#
#                                                 DQB1.1
# 0    DQB1*03:01/DQB1*03:09/DQB1*03:19/DQB1*03:21/DQ...
# 1                                           DQB1*03:02
# 2                                           DQB1*06:03
# 3                                DQB1*06:04/DQB1*06:34
# 4                                           DQB1*03:03
# ..                                                 ...
# 485                                         DQB1*02:01
# 486                                         DQB1*02:01
# 487                                         DQB1*06:03
# 488                                         DQB1*02:01
# 489                                         DQB1*03:02
#
# [490 rows x 11 columns]

# %%
mismatch_count=0
match=0
allele='A'
pred=pd.read_csv('../results/standard/hlavbseq_d2.csv')
gs=pd.read_csv('../datasets/2_gs.csv')
pred=select_allele(pred,allele)
gs=select_allele(gs,allele)
if allele=='A' or allele=='B' or allele=='C':
    index_char=7
elif allele=='DRB1' or allele=='DQB1':
    index_char=10
for index_i,row_i in pred.iterrows():
    for index_j, row_j  in gs.iterrows():
        if row_i[0]==row_j[0]:
            if '/' in row_j[allele] or '/' in row_j[allele+'.1']:
                gs_1=row_j[allele].split('/')
                gs_2=row_j[allele+'.1'].split('/')
                gs_1[:]=(elem[:index_char] for elem in gs_1)
                gs_2[:]=(elem[:index_char] for elem in gs_2)
                if row_i[allele][:index_char] not in gs_1 and row_i[allele][:index_char] not in gs_2:
                    print(row_i[allele][:index_char],gs_1,gs_2,row_i[0],row_j[0])
                    mismatch_count+=1
                if row_i[allele+'.1'][:index_char] not in gs_1 and row_i[allele+'.1'][:index_char] not in gs_2:
                    print (row_i[allele+'.1'][:index_char],gs_1,gs_2,row_i[0],row_j[0])
                    mismatch_count+=1
print(mismatch_count)
# Out:
# A*02:02 ['A*02:05', 'A*02:17'] ['A*24:02', 'A*24:09', 'A*24:11', 'A*24:40', 'A*24:76', 'A*24:79', 'A*24:83'] ERR188026 ERR188026
# A*24:02 ['A*23:01', 'A*23:07', 'A*23:17', 'A*23:18', 'A*23:20'] ['A*36:01'] ERR188030 ERR188030
# A*36:03 ['A*23:01', 'A*23:07', 'A*23:17', 'A*23:18', 'A*23:20'] ['A*36:01'] ERR188030 ERR188030
# A*31:11 ['A*31:01', 'A*31:14', 'A*31:23'] ['A*68:01'] ERR188053 ERR188053
# A*26:01 ['A*03:01', 'A*03:20', 'A*03:21', 'A*03:26', 'A*03:37', 'A*03:45'] ['A*25:01', 'A*25:07'] ERR188117 ERR188117
# A*68:35 ['A*03:01', 'A*03:20', 'A*03:21', 'A*03:26', 'A*03:37', 'A*03:45'] ['A*68:01', 'A*68:11', 'A*68:33'] ERR188169 ERR188169
# A*68:35 ['A*01:02'] ['A*68:01', 'A*68:11', 'A*68:33'] ERR188197 ERR188197
# A*30:10 ['A*30:01', 'A*30:24'] ['A*33:03', 'A*33:15', 'A*33:25'] ERR188284 ERR188284
# A*02:02 ['A*01:01', 'A*01:04', 'A*01:22', 'A*01:32', 'A*01:34', 'A*01:37'] ['A*02:05', 'A*02:17'] ERR188328 ERR188328
# A*30:70 ['A*11:01', 'A*11:21'] ['A*30:02'] ERR188342 ERR188342
# A*26:01 ['A*01:01', 'A*01:04', 'A*01:22', 'A*01:32', 'A*01:34', 'A*01:37'] ['A*25:01', 'A*25:07'] ERR188351 ERR188351
# A*26:01 ['A*11:01', 'A*11:21'] ['A*25:01', 'A*25:07'] ERR188353 ERR188353
# A*02:01 ['A*02:17'] ['A*11:01', 'A*11:21'] ERR188424 ERR188424
# A*02:02 ['A*02:01', 'A*02:09', 'A*02:43', 'A*02:66', 'A*02:75', 'A*02:83', 'A*02:89', 'A*02:97', 'A*02:13', 'A*02:14'] ['A*02:05', 'A*02:17'] ERR188448 ERR188448
# A*02:01 ['A*02:24'] ['A*11:01', 'A*11:21'] ERR188456 ERR188456
# A*02:13 ['A*02:24'] ['A*11:01', 'A*11:21'] ERR188456 ERR188456
# A*30:10 ['A*30:01', 'A*30:24'] ['A*33:03', 'A*33:15', 'A*33:25'] ERR204820 ERR204820
# A*36:03 ['A*23:01', 'A*23:07', 'A*23:17', 'A*23:18', 'A*23:20'] ['A*36:01'] ERR204994 ERR204994
# 18

# %% [markdown]
# # Mismatch

# %% [markdown]
# ## D1 Mismatch

# %%
tool_list=["arcas","hlaforest","hlavbseq","optitype","phlat","rna2hla","seq2hla"]
gs_list=["1"]
allele_list=["A","B","C"]
d1=mismatch_df(tool_list,gs_list,allele_list)
d1
# Out:
#          Tool GS Allele  Mismatch
# 0       arcas  1      A        18
# 1       arcas  1      B        37
# 2       arcas  1      C        19
# 3   hlaforest  1      A         5
# 4   hlaforest  1      B        11
# 5   hlaforest  1      C        20
# 6    hlavbseq  1      A         6
# 7    hlavbseq  1      B        16
# 8    hlavbseq  1      C         8
# 9    optitype  1      A         4
# 10   optitype  1      B         5
# 11   optitype  1      C         4
# 12      phlat  1      A        10
# 13      phlat  1      B        15
# 14      phlat  1      C        13
# 15    rna2hla  1      A         5
# 16    rna2hla  1      B         9
# 17    rna2hla  1      C         7
# 18    seq2hla  1      A         5
# 19    seq2hla  1      B         9
# 20    seq2hla  1      C         7

# %% [markdown]
# ## D2 Mismatch

# %%
tool_list=["arcas","hlaforest","hlavbseq","optitype","phlat","rna2hla","seq2hla"]
gs_list=["2"]
allele_list=["A","B","C"]
d2_class1=mismatch_df(tool_list,gs_list,allele_list)
d2_class1
# Out:
#          Tool GS Allele  Mismatch
# 0       arcas  2      A        59
# 1       arcas  2      B         7
# 2       arcas  2      C        25
# 3   hlaforest  2      A        39
# 4   hlaforest  2      B       141
# 5   hlaforest  2      C        90
# 6    hlavbseq  2      A        18
# 7    hlavbseq  2      B        88
# 8    hlavbseq  2      C        52
# 9    optitype  2      A         2
# 10   optitype  2      B         7
# 11   optitype  2      C         1
# 12      phlat  2      A        31
# 13      phlat  2      B       107
# 14      phlat  2      C        45
# 15    rna2hla  2      A        10
# 16    rna2hla  2      B        24
# 17    rna2hla  2      C        12
# 18    seq2hla  2      A        10
# 19    seq2hla  2      B        24
# 20    seq2hla  2      C        12

# %%
tool_list=["arcas","hlaforest","hlavbseq","phlat","rna2hla","seq2hla"]
gs_list=["2"]
allele_list=["DRB1"]
d2_drb=mismatch_df(tool_list,gs_list,allele_list)
d2_drb
# Out:
#         Tool GS Allele  Mismatch
# 0      arcas  2   DRB1         0
# 1  hlaforest  2   DRB1         1
# 2   hlavbseq  2   DRB1        64
# 3      phlat  2   DRB1         4
# 4    rna2hla  2   DRB1         2
# 5    seq2hla  2   DRB1         2

# %%
tool_list=["arcas","hlaforest","hlavbseq","phlat"]
gs_list=["2"]
allele_list=["DQB1"]
d2_dqb=mismatch_df(tool_list,gs_list,allele_list)
d2_dqb
# Out:
#         Tool GS Allele  Mismatch
# 0      arcas  2   DQB1        10
# 1  hlaforest  2   DQB1        22
# 2   hlavbseq  2   DQB1         0
# 3      phlat  2   DQB1       164

# %% [markdown]
# ## D3 Mismatch

# %%
tool_list=["arcas","hlaforest","hlavbseq","phlat","rna2hla","seq2hla"]
gs_list=["3"]
allele_list=["DRB1"]
d3=mismatch_df(tool_list,gs_list,allele_list)
d3
# Out:
#         Tool GS Allele  Mismatch
# 0      arcas  3   DRB1         5
# 1  hlaforest  3   DRB1        24
# 2   hlavbseq  3   DRB1        55
# 3      phlat  3   DRB1        12
# 4    rna2hla  3   DRB1        38
# 5    seq2hla  3   DRB1        52

# %% [markdown]
# ## D4 Mismatch

# %%
tool_list=["arcas","hlaforest","hlavbseq","phlat","rna2hla","seq2hla"]
gs_list=["4"]
allele_list=["DRB1"]
d4=mismatch_df(tool_list,gs_list,allele_list)
d4
# Out:
#         Tool GS Allele  Mismatch
# 0      arcas  4   DRB1        12
# 1  hlaforest  4   DRB1         6
# 2   hlavbseq  4   DRB1        11
# 3      phlat  4   DRB1         3
# 4    rna2hla  4   DRB1        10
# 5    seq2hla  4   DRB1        10

# %% [markdown]
# ## D5 Mismatch

# %%
tool_list=["arcas","hlaforest","hlavbseq","optitype","phlat","rna2hla","seq2hla"]
gs_list=["5"]
allele_list=["A","B"]
d5=mismatch_df(tool_list,gs_list,allele_list)
d5
# Out:
#          Tool GS Allele  Mismatch
# 0       arcas  5      A         2
# 1       arcas  5      B         1
# 2   hlaforest  5      A         4
# 3   hlaforest  5      B         3
# 4    hlavbseq  5      A         1
# 5    hlavbseq  5      B         1
# 6    optitype  5      A         4
# 7    optitype  5      B         1
# 8       phlat  5      A         3
# 9       phlat  5      B         1
# 10    rna2hla  5      A         4
# 11    rna2hla  5      B         2
# 12    seq2hla  5      A         4
# 13    seq2hla  5      B         2

# %% [markdown]
# ## D6 Mismatch

# %%
tool_list=["arcas","hlaforest","hlavbseq","optitype","phlat","rna2hla","seq2hla"]
gs_list=["6"]
allele_list=["C"]
d6=mismatch_df(tool_list,gs_list,allele_list)
d6
# Out:
#         Tool GS Allele  Mismatch
# 0      arcas  6      C         0
# 1  hlaforest  6      C         0
# 2   hlavbseq  6      C         1
# 3   optitype  6      C         5
# 4      phlat  6      C         0
# 5    rna2hla  6      C         2
# 6    seq2hla  6      C         2

# %% [markdown]
# # Plots

# %%
df=pd.concat([d1,d2_class1,d2_dqb,d2_drb,d3,d4,d5,d6])
df
# Out:
#          Tool GS Allele  Mismatch
# 0       arcas  1      A        18
# 1       arcas  1      B        37
# 2       arcas  1      C        19
# 3   hlaforest  1      A         5
# 4   hlaforest  1      B        11
# ..        ... ..    ...       ...
# 2    hlavbseq  6      C         1
# 3    optitype  6      C         5
# 4       phlat  6      C         0
# 5     rna2hla  6      C         2
# 6     seq2hla  6      C         2
#
# [85 rows x 4 columns]

# %%
#df['norm'] = (1+df['Mismatch'])/2
df['lognorm'] = np.log10(df['Mismatch'])
# Out:
# /home/curryofdoom/anaconda3/envs/panel/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
conditions = [
    (df['Allele'] == 'A') | (df['Allele'] == 'B') | (df['Allele'] == 'C'),
    (df['Allele'] == 'DRB1') | (df['Allele'] == 'DQB1')
    ]
values =['Class 1','Class 2']
df['Class'] =np.select(conditions,values)
df
# Out:
#          Tool GS Allele  Mismatch   lognorm    Class
# 0       arcas  1      A        18  1.255273  Class 1
# 1       arcas  1      B        37  1.568202  Class 1
# 2       arcas  1      C        19  1.278754  Class 1
# 3   hlaforest  1      A         5  0.698970  Class 1
# 4   hlaforest  1      B        11  1.041393  Class 1
# ..        ... ..    ...       ...       ...      ...
# 2    hlavbseq  6      C         1  0.000000  Class 1
# 3    optitype  6      C         5  0.698970  Class 1
# 4       phlat  6      C         0      -inf  Class 1
# 5     rna2hla  6      C         2  0.301030  Class 1
# 6     seq2hla  6      C         2  0.301030  Class 1
#
# [85 rows x 6 columns]

# %%
palette ={"A": "#40739f", "B": "#4f8ec5", "C": "#2b4e6c", "DQB1": "tab:orange","DRB1" : "#ffa744" }
sns.set(rc={'figure.figsize':(10,10)})
sns.set_context("paper")
#sns.dark_palette("C0", reverse=True, as_cmap=True)
#sns.set_palette(sns.color_palette(colors))
#sns.color_palette("pastel")
sns.set_style("white")
ax=sns.barplot(x='Tool',y='Mismatch', hue='Allele', data=df, ci=None, palette=palette)
#ax = sns.catplot(x='Tool',y='Mismatch',hue='Allele',data=df,kind='bar',ci=None).set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set_xticklabels(['ArcasHLA','HLAForest','HLA-VBSeq','Optitype','PHLAT','RNA2HLA','Seq2HLA'], rotation=45)
plt.xlabel("Callers")
plt.ylabel("Count")
plt.annotate("Class 1",
            xy=(0.31, 0.7), xycoords='figure fraction',
            xytext=(0.805,  0.82), textcoords='figure fraction',
            arrowprops=dict(arrowstyle="-",lw=0))
plt.annotate(r"$\{$",fontsize=30,
            xy=(0.85, 0.815), xycoords='figure fraction'
            )
plt.annotate("Class 2",
            xy=(0.31, 0.7), xycoords='figure fraction',
            xytext=(0.805,  0.77), textcoords='figure fraction',
            arrowprops=dict(arrowstyle="-",lw=0))
plt.annotate(r"$\{$",fontsize=30,
            xy=(0.85, 0.765), xycoords='figure fraction'
            )
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

sns.despine()
plt.savefig('../Figures/miscalled_alleles.png', bbox_inches="tight",dpi=300)

# %%
palette ={"A": "#40739f", "B": "#4f8ec5", "C": "#2b4e6c", "DQB1": "tab:orange","DRB1" : "#ffa744" }
sns.set(rc={'figure.figsize':(10,10)})
sns.set_context("paper")
#sns.dark_palette("C0", reverse=True, as_cmap=True)
#sns.set_palette(sns.color_palette(colors))
#sns.color_palette("pastel")
sns.set_style("white")
ax=sns.barplot(x='Tool',y='Mismatch', hue='Allele', data=df, ci=None, palette=palette)
#ax = sns.catplot(x='Tool',y='Mismatch',hue='Allele',data=df,kind='bar',ci=None).set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set_xticklabels(['ArcasHLA','HLAForest','HLA-VBSeq','Optitype','PHLAT','RNA2HLA','Seq2HLA'], rotation=45)
plt.xlabel("Callers")
plt.ylabel("Count")
plt.annotate("Class 1",
            xy=(0.31, 0.7), xycoords='figure fraction',
            xytext=(0.805,  0.82), textcoords='figure fraction',
            arrowprops=dict(arrowstyle="-",lw=0))
plt.annotate(r"$\{$",fontsize=30,
            xy=(0.85, 0.815), xycoords='figure fraction'
            )
plt.annotate("Class 2",
            xy=(0.31, 0.7), xycoords='figure fraction',
            xytext=(0.805,  0.77), textcoords='figure fraction',
            arrowprops=dict(arrowstyle="-",lw=0))
plt.annotate(r"$\{$",fontsize=30,
            xy=(0.85, 0.765), xycoords='figure fraction'
            )
for i in ax.containers:
    ax.bar_label(i,)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

sns.despine()
plt.savefig('../Figures/miscalled_alleles.png', bbox_inches="tight",dpi=300)

# %%
palette ={"A": "#40739f", "B": "#4f8ec5", "C": "#2b4e6c", "DQB1": "tab:orange","DRB1" : "#ffa744" }
sns.set(rc={'figure.figsize':(10,10)})
sns.set_context("paper")
#sns.dark_palette("C0", reverse=True, as_cmap=True)
#sns.set_palette(sns.color_palette(colors))
#sns.color_palette("pastel")
sns.set_style("white")
ax=sns.barplot(x='Tool',y='lognorm', hue='Allele', data=df, ci=None, palette=palette)
#ax = sns.catplot(x='Tool',y='Mismatch',hue='Allele',data=df,kind='bar',ci=None).set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set_xticklabels(['ArcasHLA','HLAForest','HLA-VBSeq','Optitype','PHLAT','RNA2HLA','Seq2HLA'], rotation=45)
plt.xlabel("Callers")
plt.ylabel("Count (Log10 Scaled")
plt.annotate("Class 1",
            xy=(0.31, 0.7), xycoords='figure fraction',
            xytext=(0.805,  0.82), textcoords='figure fraction',
            arrowprops=dict(arrowstyle="-",lw=0))
plt.annotate(r"$\{$",fontsize=30,
            xy=(0.85, 0.815), xycoords='figure fraction'
            )
plt.annotate("Class 2",
            xy=(0.31, 0.7), xycoords='figure fraction',
            xytext=(0.805,  0.77), textcoords='figure fraction',
            arrowprops=dict(arrowstyle="-",lw=0))
plt.annotate(r"$\{$",fontsize=30,
            xy=(0.85, 0.765), xycoords='figure fraction'
            )
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

sns.despine()
plt.savefig('../Figures/miscalled_alleles_log.png', bbox_inches="tight",dpi=300)

# %%
palette ={"A": "#40739f", "B": "#4f8ec5", "C": "#2b4e6c", "DQB1": "tab:orange","DRB1" : "#ffa744" }
sns.set(rc={'figure.figsize':(10,10)})
sns.set_context("paper")
#sns.dark_palette("C0", reverse=True, as_cmap=True)
#sns.set_palette(sns.color_palette(colors))
#sns.color_palette("pastel")
sns.set_style("white")
ax=sns.barplot(x='Allele',y='Mismatch', data=df, ci=None)
#ax = sns.catplot(x='Tool',y='Mismatch',hue='Allele',data=df,kind='bar',ci=None).set(title="Number of Miscalled Alleles Across Datasets 1-6 (n=652)")
ax.set(title="Number of Miscalls per Allele Across Datasets 1-6 (n=652)")
#ax.set_xticklabels(['ArcasHLA','HLAForest','HLA-VBSeq','Optitype','PHLAT','RNA2HLA','Seq2HLA'], rotation=45)
plt.xlabel("Allele")
plt.ylabel("Count")

sns.despine()
#plt.savefig('../Figures/miscalled_alleles_log.png', bbox_inches="tight",dpi=300)
