# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import seaborn as sns
from utils import *
import matplotlib.patches as mpatches

# %%
# COLORS FOR ACCURACY

labels = [
mpatches.Patch(color=palette[2], label="One-field accuracy"),
mpatches.Patch(color=palette[1], label="Two-field accuracy"),
mpatches.Patch(color=palette[0], label="No call"),
] 
plt.legend(handles=labels, ncol=len(labels),fontsize=30,bbox_to_anchor=(0.5, -.03),frameon=False)

# %%
# COLORS FOR LOCUS

labels = [
mpatches.Patch(color=palette[3], label="A"),
mpatches.Patch(color=palette[4], label="B"),
mpatches.Patch(color=palette[5], label="C"),
mpatches.Patch(color=palette[6], label="DRB1"),
mpatches.Patch(color=palette[7], label="DQB1")
] 
plt.legend(handles=labels, ncol=len(labels),fontsize=30,bbox_to_anchor=(0.5, -.03),frameon=False)

# %%
# COLORS FOR ANCESTRY

labels = [
mpatches.Patch(color=palette[8], label="Europe"),
mpatches.Patch(color=palette[9], label="Yoruba"),

] 
plt.legend(handles=labels, ncol=len(labels),fontsize=30,bbox_to_anchor=(0.5, -.03),frameon=False)
