# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("old/2_gs_edited.csv")
df
# Out:
#            Run                                                  A  \
# 0    ERR188021                01:01/01:04/01:22/01:32/01:34/01:37
# 1    ERR188023  02:01/02:09/02:43/02:66/02:75/02:83/02:89/02:9...
# 2    ERR188025                03:01/03:20/03:21/03:26/03:37/03:45
# 3    ERR188026                                        02:05/02:17
# 4    ERR188027                                               1:01
# ..         ...                                                ...
# 485  ERR205017                                           30:02:00
# 486  ERR205019                                           24:24:00
# 487  ERR205021                03:01/03:20/03:21/03:26/03:37/03:45
# 488  ERR205022                                               1:01
# 489  ERR205023                                               2:01
#
#                                            A.1                        B  \
# 0    24:02/24:09/24:11/24:40/24:76/24:79/24:83                 41:02:00
# ...

# %%
df.dropna(how='all', axis=1, inplace=True)
df
# Out:
#            Run                                                  A  \
# 0    ERR188021                01:01/01:04/01:22/01:32/01:34/01:37
# 1    ERR188023  02:01/02:09/02:43/02:66/02:75/02:83/02:89/02:9...
# 2    ERR188025                03:01/03:20/03:21/03:26/03:37/03:45
# 3    ERR188026                                        02:05/02:17
# 4    ERR188027                                               1:01
# ..         ...                                                ...
# 485  ERR205017                                           30:02:00
# 486  ERR205019                                           24:24:00
# 487  ERR205021                03:01/03:20/03:21/03:26/03:37/03:45
# 488  ERR205022                                               1:01
# 489  ERR205023                                               2:01
#
#                                            A.1                        B  \
# 0    24:02/24:09/24:11/24:40/24:76/24:79/24:83                 41:02:00
# ...

# %%
test=df['A'][485]
len(test)
# Out:
# 8

# %%
for col in df.columns[df.columns!='Run']:
    if '.' in col:
        allele = col.split('.')[0]
        for i in range(len(df[col])):
            if '/' in df[col][i]:
                sample_list=df[col][i].split('/')
                for j in range(len(sample_list)):
                    value=allele+'*' + sample_list[j]
                    sample_list[j] = value
                string='/'.join(sample_list)
                df[col][i]=string
            elif len(df[col][i])==4:
                df[col][i]=allele+'*0'+df[col][i]
            else:
                df[col][i]=allele+'*'+ df[col][i]
    else: 
        for i in range(len(df[col])):
            if '/' in df[col][i]:
                sample_list=df[col][i].split('/')
                for j in range(len(sample_list)):
                    value=col+'*' + sample_list[j]
                    sample_list[j] = value
                string='/'.join(sample_list)
                df[col][i]=string
            elif len(df[col][i])==4:
                df[col][i]=col+'*0'+df[col][i]    
            else:
                 df[col][i]=col+'*'+ df[col][i]

# %%
df['A'][1:7]
# Out:
# 1    A*02:01/A*02:09/A*02:43/A*02:66/A*02:75/A*02:8...
# 2      A*03:01/A*03:20/A*03:21/A*03:26/A*03:37/A*03:45
# 3                                      A*02:05/A*02:17
# 4                                               A*1:01
# 5    A*02:01/A*02:09/A*02:43/A*02:66/A*02:75/A*02:8...
# 6      A*03:01/A*03:20/A*03:21/A*03:26/A*03:37/A*03:45
# Name: A, dtype: object

# %%
df
# Out:
#            Run                                                  A  \
# 0    ERR188021    A*01:01/A*01:04/A*01:22/A*01:32/A*01:34/A*01:37
# 1    ERR188023  A*02:01/A*02:09/A*02:43/A*02:66/A*02:75/A*02:8...
# 2    ERR188025    A*03:01/A*03:20/A*03:21/A*03:26/A*03:37/A*03:45
# 3    ERR188026                                    A*02:05/A*02:17
# 4    ERR188027                                            A*01:01
# ..         ...                                                ...
# 485  ERR205017                                         A*30:02:00
# 486  ERR205019                                         A*24:24:00
# 487  ERR205021    A*03:01/A*03:20/A*03:21/A*03:26/A*03:37/A*03:45
# 488  ERR205022                                            A*01:01
# 489  ERR205023                                            A*02:01
#
#                                                    A.1  \
# 0    A*24:02/A*24:09/A*24:11/A*24:40/A*24:76/A*24:7...
# 1                                      A*30:01/A*30:24
# ...

# %%
df.to_csv("2_gs.csv")
