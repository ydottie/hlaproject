# %%
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
# Out:
# Mounted at /content/gdrive

# %%
loc = '/content/gdrive/MyDrive/datasets/raw/'
f1 = loc+'father1.gtf'
f2 = loc+'father2.gtf'
m1 = loc+'mother1.gtf'
m2 = loc+'mother2.gtf'
d1 = loc+'daughter1.gtf'
d2 = loc+'daughter2.gtf'

# %%
# prompt: read p as a tsv in pandas, with 10 columns labeled a,b,c,...

df = pd.read_csv(f1, sep='\t', names=['a','b','c','d','e','f','g','h','i'])
df
# Out:
#                                                      a                     b  \
# 0                                       ## format: gtf                   NaN
# 1                                  ## date: 2024-05-22                   NaN
# 2    ## gene (copy num = 0): HLA-DRB2,HLA-DRB3,HLA-...                   NaN
# 3    ## gene (copy num = 1): HLA-A,HLA-B,HLA-C,HLA-...                   NaN
# 4     ## contigs for IPD-IMGT/HLA-V3.52.0: h1tg000051l                   NaN
# ..                                                 ...                   ...
# 943                                        h1tg000051l  IPD-IMGT/HLA-V3.52.0
# 944                                        h1tg000051l  IPD-IMGT/HLA-V3.52.0
# 945                                        h1tg000051l  IPD-IMGT/HLA-V3.52.0
# 946                                        h1tg000051l  IPD-IMGT/HLA-V3.52.0
# 947                                        h1tg000051l  IPD-IMGT/HLA-V3.52.0
#
# ...

# %%
l = df['c'].tolist()
s = set(l)
s
# Out:
# {'CDS', 'UTR', 'exon', 'gene', nan, 'start_codon', 'stop_codon', 'transcript'}

# %%
df_filtered = df[df['c']=='transcript']
df_filtered

alleles=[]
for i in df_filtered['i']:
  d = i.split('; ')
  if (d[2] == 'gene_name "HLA-A"'):
    alleles.append(d[3])
  if (d[2] == 'gene_name "HLA-B"'):
    alleles.append(d[3])
  if (d[2] == 'gene_name "HLA-C"'):
    alleles.append(d[3])
  if (d[2] == 'gene_name "HLA-DRB1"'):
    alleles.append(d[3])
  if (d[2] == 'gene_name "HLA-DQB1"'):
    alleles.append(d[3])

alleles
# Out:
# ['consensus "HLA-A*24:02:01:05"',
#  'consensus "HLA-C*12:03:01:01"',
#  'consensus "HLA-B*38:01:01:01"',
#  'consensus "HLA-DRB1*07:01:01:01"',
#  'consensus "HLA-DQB1*02:02:01:01"']
